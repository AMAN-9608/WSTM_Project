# %%
import gzip
import json
import re
import os
import sys
import numpy as np
import pandas as pd
import pickle

# %%
user_emb = pd.read_pickle('user.pickle')
item_emb = pd.read_pickle('item.pickle')
R_ui = pd.read_pickle('user_dict.pickle')
R_iu = pd.read_pickle('item_dict.pickle')

# %%
user_emb
# Out:
# defaultdict(<function numpy.array>,
#             {'0': array([0.288239  , 0.37552256, 0.31567088, 0.28592683, 0.22263737,
#                     0.33746718, 0.22935844, 0.466421  , 0.50259061, 0.2012313 ,
#                     0.41333611, 0.27794046, 0.2973072 , 0.48494148, 0.03980874]),
#              '1': array([0.0420404 , 0.00675889, 0.42859622, 0.40018949, 0.44780734,
#                     0.50448761, 0.41133106, 0.23597082, 0.40143645, 0.0578498 ,
#                     0.32860776, 0.07074162, 0.48711763, 0.26745728, 0.21160183]),
#              '2': array([0.13884878, 0.40352297, 0.23705163, 0.29519161, 0.01026157,
#                     0.32207206, 0.31827961, 0.32107195, 0.49049308, 0.35493974,
#                     0.18675618, 0.22757615, 0.36335614, 0.03229398, 0.3475942 ]),
#              '8': array([0.3623112 , 0.12424635, 0.08225697, 0.17906003, 0.20398927,
#                     0.31019115, 0.24126432, 0.52795945, 0.06828377, 0.12307728,
# ...
